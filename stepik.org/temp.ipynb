# %%
import pandas as pd
import numpy as np

# %%
class Math_solver:
    init(self, n):
        self.n = n

# %%
for i in []:
    print(48_652_974 / i)
# Out:
# 12163243.5
# 6081621.75
# 5405886.0

# %%
s = '48652974'

print(sum([int(i) for i in s]))
# Out:
# 45

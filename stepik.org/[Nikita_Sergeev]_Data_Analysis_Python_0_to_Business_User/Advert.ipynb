# %% [markdown]
# # Библиотеки

# %%
import pandas as pd
import numpy as np
from scipy import stats
import pingouin as pg
import seaborn as sns

# %% [markdown]
# ## 9.11 Тест 2-х групп (почти самостоятельное задание)

# %%
filepath = './data/SPSS14.sav'

d = pd.read_spss(filepath)

# %%
d.groupby('Реклама', observed=False)['Эффект'].describe()
# Out:
#            count      mean       std  min  25%  50%  75%   max
# Реклама
# Реклама1  2521.0  7.431971  1.728678  1.0  6.0  8.0  9.0  10.0
# Реклама2  2680.0  4.097388  2.098684  1.0  2.0  4.0  6.0  10.0

# %%
d.plot.hist(column='Эффект', by='Реклама', sharex=True, sharey=True)
# Out:
# C:\Users\ilyao\AppData\Local\Temp\ipykernel_12744\4089731210.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d.plot.hist(column='Эффект', by='Реклама', sharex=True, sharey=True)
# C:\Users\ilyao\AppData\Local\Temp\ipykernel_12744\4089731210.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d.plot.hist(column='Эффект', by='Реклама', sharex=True, sharey=True)
# ...

# %%
d.plot.box(column='Эффект', by='Реклама', sharex=True, sharey=True)
# Out:
# C:\Users\ilyao\AppData\Local\Temp\ipykernel_12744\2362075908.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d.plot.box(column='Эффект', by='Реклама', sharex=True, sharey=True)
# Эффект    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
pg.ttest(
    x=d[d['Реклама']=='Реклама1']['Эффект'],
    y=d[d['Реклама']=='Реклама2']['Эффект']
)
# Out:
#                T          dof alternative  p-val         CI95%   cohen-d BF10  \
# T-test  62.69572  5110.740177   two-sided    0.0  [3.23, 3.44]  1.729353  inf
#
#         power
# T-test    1.0

# %% [markdown]
# # Библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 123

# %%
df = pd.read_excel('./data/PQAssignm7.xlsx')

# %% [markdown]
# # end
